# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = [5, 10, 15]
y = [1, 1, 1]
s = [5000, 10000, 15000]

plt.figure(figsize=(12,8))
plt.scatter(x, y, s=s)
plt.axis((0, 20, 0, 2))
# Out:
# (0, 20, 0, 2)

# %% [markdown]
# ![Rplot_circles.png](attachment:Rplot_circles.png)
