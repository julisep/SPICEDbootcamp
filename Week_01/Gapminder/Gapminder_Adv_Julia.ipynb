# %% [markdown]
# # Gapminder Project Julia

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import pylab as plt
import imageio
import seaborn as sns

# %% [markdown]
# ### Read data

# %%
fert = pd.read_csv('/Users/julia/Downloads/gapminder_total_fertility.csv', index_col=0)
life = pd.read_excel('/Users/julia/Downloads/gapminder_lifeexpectancy.xlsx', index_col=0)
pop = pd.read_excel('/Users/julia/Downloads/gapminder_population.xlsx', index_col=0)
continents = pd.read_csv('/Users/julia/Downloads/continents.csv', sep = ';')

# %% [markdown]
# ### Inspect dataframes

# %%
fert.head()
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
#
#                        1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# Total fertility rate         ...
# Abkhazia                NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14
# Akrotiri and Dhekelia   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76
# Algeria                6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82
#
#                        2013  2014  2015
# Total fertility rate
# Abkhazia                NaN   NaN   NaN
# Afghanistan            4.90  4.68  4.47
# Akrotiri and Dhekelia   NaN   NaN   NaN
# Albania                1.77  1.78  1.78
# Algeria                2.80  2.76  2.71
#
# [5 rows x 216 columns]

# %%
life.head()
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#                         1808   1809  ...  2007  2008  2009  2010  2011  2012  \
# Life expectancy                      ...
# Abkhazia                 NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            28.13  28.12  ...  52.4  52.8  53.3  53.6  54.0  54.4
# Akrotiri and Dhekelia    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5
# Algeria                28.82  28.82  ...  75.3  75.5  75.7  76.0  76.1  76.2
#
#                        2013  2014  2015   2016
# Life expectancy
# Abkhazia                NaN   NaN   NaN    NaN
# Afghanistan            54.8  54.9  53.8  52.72
# Akrotiri and Dhekelia   NaN   NaN   NaN    NaN
# Albania                77.7  77.9  78.0  78.10
# Algeria                76.3  76.3  76.4  76.50
#
# [5 rows x 217 columns]

# %%
pop.head()
# Out:
#                             1800       1810       1820       1830       1840  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 410445.0   423591.0   438671.0   457234.0   478227.0
# Algeria                2503218.0  2595056.0  2713079.0  2880355.0  3082721.0
#
#                             1850       1860       1870       1880       1890  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3810047.0  3973968.0  4169690.0  4419695.0  4710171.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 506889.0   552800.0   610036.0   672544.0   741688.0
# Algeria                3299305.0  3536468.0  3811028.0  4143163.0  4525691.0
#
#                        ...        2006        2007        2008        2009  \
# Total population       ...
# Abkhazia               ...         NaN         NaN         NaN         NaN
# Afghanistan            ...  25183615.0  25877544.0  26528741.0  27207291.0
# Akrotiri and Dhekelia  ...     15700.0     15700.0     15700.0         NaN
# Albania                ...   3050741.0   3010849.0   2968026.0   2929886.0
# Algeria                ...  33749328.0  34261971.0  34811059.0  35401790.0
#
#                              2010        2011        2012        2013  \
# Total population
# Abkhazia                      NaN         NaN         NaN         NaN
# Afghanistan            27962207.0  28809167.0  29726803.0  30682500.0
# Akrotiri and Dhekelia         NaN         NaN         NaN         NaN
# Albania                 2901883.0   2886010.0   2880667.0   2883281.0
# Algeria                36036159.0  36717132.0  37439427.0  38186135.0
#
#                              2014        2015
# Total population
# Abkhazia                      NaN         NaN
# Afghanistan            31627506.0  32526562.0
# Akrotiri and Dhekelia         NaN         NaN
# Albania                 2889676.0   2896679.0
# Algeria                38934334.0  39666519.0
#
# [5 rows x 81 columns]

# %%
print('life shape:' + str(life.shape) + '\nfert shape:' + str(fert.shape) + '\npop shape:' + str(pop.shape))
# Out:
# life shape:(260, 217)
# fert shape:(260, 216)
# pop shape:(275, 81)

# %% [markdown]
# ### Inspect columns (need to be the same for stacking and combining later on)

# %%
fert.columns
# Out:
# Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object', length=216)

# %%
ncol = [int(x) for x in fert.columns]
fert.set_axis(axis=1, labels=ncol, inplace=True)

# %%
life.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#            dtype='int64', length=217)

# %%
pop.columns
# Out:
# Int64Index([1800, 1810, 1820, 1830, 1840, 1850, 1860, 1870, 1880, 1890, 1900,
#             1910, 1920, 1930, 1940, 1950, 1951, 1952, 1953, 1954, 1955, 1956,
#             1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
#             1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978,
#             1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#             1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#             2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015],
#            dtype='int64')

# %% [markdown]
# ### Convert dataframes to lonf format in preparation for merging

# %%
sfert = fert.stack()
slife = life.stack()
spop = pop.stack()

# %% [markdown]
# ### Create dataframe from all three datasets in long format

# %%
d = {'fertility': sfert, 'lifeexp': slife, 'population': spop}
df2 = pd.DataFrame(d)
df2.head(12)
# Out:
#                   fertility  lifeexp  population
# Afghanistan 1800        7.0    28.21   3280000.0
#             1801        7.0    28.20         NaN
#             1802        7.0    28.19         NaN
#             1803        7.0    28.18         NaN
#             1804        7.0    28.17         NaN
#             1805        7.0    28.16         NaN
#             1806        7.0    28.15         NaN
#             1807        7.0    28.14         NaN
#             1808        7.0    28.13         NaN
#             1809        7.0    28.12         NaN
#             1810        7.0    28.11   3280000.0
#             1811        7.0    28.10         NaN

# %% [markdown]
# ### Stack also the three columns to have only one column with values

# %%
df3 = df2.stack()
df3
# Out:
# Afghanistan  1800  fertility           7.00
#                    lifeexp            28.21
#                    population    3280000.00
#              1801  fertility           7.00
#                    lifeexp            28.20
#                                     ...
# Åland        2006  population      26923.00
#              2007  population      26923.00
#              2008  population      26923.00
#              2009  population      26923.00
#              2010  population      26923.00
# Length: 107445, dtype: float64

# %% [markdown]
# ### Convert back to wide table with country and quantity as columns and year as indices

# %%
df4 = df3.unstack((0,2))
df4
# Out:
#      Afghanistan                     Akrotiri and Dhekelia   Albania          \
#        fertility lifeexp  population            population fertility lifeexp
# 1800        7.00   28.21   3280000.0                   NaN      4.60    35.4
# 1801        7.00   28.20         NaN                   NaN      4.60    35.4
# 1802        7.00   28.19         NaN                   NaN      4.60    35.4
# 1803        7.00   28.18         NaN                   NaN      4.60    35.4
# 1804        7.00   28.17         NaN                   NaN      4.60    35.4
# ...          ...     ...         ...                   ...       ...     ...
# 2012        5.14   54.40  29726803.0                   NaN      1.76    77.5
# 2013        4.90   54.80  30682500.0                   NaN      1.77    77.7
# 2014        4.68   54.90  31627506.0                   NaN      1.78    77.9
# 2015        4.47   53.80  32526562.0                   NaN      1.78    78.0
# 2016         NaN   52.72         NaN                   NaN       NaN    78.1
#
#                   Algeria                      ...       Yemen Yugoslavia  \
#      population fertility lifeexp  population  ...  population population
# 1800   410445.0      6.99   28.82   2503218.0  ...   2593000.0        NaN
# 1801        NaN      6.99   28.82         NaN  ...         NaN        NaN
# 1802        NaN      6.99   28.82         NaN  ...         NaN        NaN
# 1803        NaN      6.99   28.82         NaN  ...         NaN        NaN
# 1804        NaN      6.99   28.82         NaN  ...         NaN        NaN
# ...         ...       ...     ...         ...  ...         ...        ...
# 2012  2880667.0      2.82   76.20  37439427.0  ...  24882792.0        NaN
# 2013  2883281.0      2.80   76.30  38186135.0  ...  25533217.0        NaN
# 2014  2889676.0      2.76   76.30  38934334.0  ...  26183676.0        NaN
# 2015  2896679.0      2.71   76.40  39666519.0  ...  26832215.0        NaN
# 2016        NaN       NaN   76.50         NaN  ...         NaN        NaN
#
#         Zambia                      Zimbabwe                          Åland  \
#      fertility lifeexp  population fertility lifeexp  population population
# 1800      6.71    32.6    747000.0      6.75   33.70   1085814.0        NaN
# 1801      6.71    32.6         NaN      6.75   33.70         NaN        NaN
# 1802      6.71    32.6         NaN      6.75   33.70         NaN        NaN
# 1803      6.71    32.6         NaN      6.75   33.70         NaN        NaN
# 1804      6.71    32.6         NaN      6.75   33.70         NaN        NaN
# ...        ...     ...         ...       ...     ...         ...        ...
# 2012      5.73    54.7  14786581.0      3.56   54.20  14565482.0        NaN
# 2013      5.69    55.6  15246086.0      3.49   55.70  14898092.0        NaN
# 2014      5.64    56.3  15721343.0      3.41   57.00  15245855.0        NaN
# 2015      5.59    56.7  16211767.0      3.35   59.30  15602751.0        NaN
# 2016       NaN    57.1         NaN       NaN   61.69         NaN        NaN
#
#
#      lifeexp
# 1800     NaN
# 1801     NaN
# 1802     NaN
# 1803     NaN
# 1804     NaN
# ...      ...
# 2012     NaN
# 2013     NaN
# 2014     NaN
# 2015     NaN
# 2016     NaN
#
# [217 rows x 667 columns]

# %% [markdown]
# ### Select three countries and plot them

# %%
df4[['Germany', 'France', 'Sweden']].plot(figsize=(12,8))

# %% [markdown]
# ### Convert table to have quantities as columns and country and year as indices and creat scatter plot if fertility vs life expectancy

# %%
df5 = df3.unstack(2)
df5
# Out:
#                   fertility  lifeexp  population
# Afghanistan 1800        7.0    28.21   3280000.0
#             1801        7.0    28.20         NaN
#             1802        7.0    28.19         NaN
#             1803        7.0    28.18         NaN
#             1804        7.0    28.17         NaN
# ...                     ...      ...         ...
# Åland       2006        NaN    80.10     26923.0
#             2007        NaN      NaN     26923.0
#             2008        NaN      NaN     26923.0
#             2009        NaN      NaN     26923.0
#             2010        NaN      NaN     26923.0
#
# [47688 rows x 3 columns]

# %%
df5.plot.scatter('fertility', 'lifeexp', s=0.1, figsize=(12,8))
plt.title('With increasing life expectancy fertility decreases', fontsize=20)
plt.xlabel('Total fertility rate', fontsize=16)
plt.ylabel('Life expectancy / years', fontsize=16)
plt.tick_params(labelsize=14)

# %% [markdown]
# ### Create scatter plot for specific year (1950)

# %%
df6 = df3.unstack(1)
df6 = df6[1950]
df6 = df6.unstack(1)
df6
# Out:
#                        fertility  lifeexp  population
# Afghanistan                 7.67    26.85   7752118.0
# Akrotiri and Dhekelia        NaN      NaN     10661.0
# Albania                     5.80    54.48   1263171.0
# Algeria                     7.65    42.77   8872247.0
# American Samoa               NaN      NaN     18937.0
# ...                          ...      ...         ...
# Yemen                       7.27    23.51   4402320.0
# Yugoslavia                   NaN      NaN  16285527.0
# Zambia                      6.71    42.85   2316950.0
# Zimbabwe                    6.75    48.46   2746854.0
# Åland                        NaN      NaN     21649.0
#
# [256 rows x 3 columns]

# %%
df6.plot.scatter('fertility', 'lifeexp', s=10, figsize=(12,8))

# %% [markdown]
# Add different colours for each country

# %%
cmap = plt.get_cmap('tab20', lut = len(df6)).colors
df6.plot.scatter('fertility', 'lifeexp', s=10, figsize=(12,8), c=cmap)

# %% [markdown]
# Make the circles represent the population size of each country

# %%
c_size = df6['population']/100000
df6.plot.scatter('fertility', 'lifeexp', s=c_size, figsize=(12,8), c=cmap, alpha=0.7)
plt.title('1950', fontsize=20, y= 1.02)
plt.xlabel('Total fertility rate', fontsize=16)
plt.ylabel('Life expectancy [years]', fontsize=16)
plt.tick_params(labelsize=14)

# %% [markdown]
# Try out seaborn..

# %%
c_size = df6['population']/100000
sns.set(font_scale=1.6)
df6.plot.scatter('fertility', 'lifeexp', s=c_size, figsize=(12,8), c=cmap, alpha=0.6)
plt.axis((0, 10, 0, 100))
plt.title('1950', y= 1.02, fontsize = 30, weight='bold')
plt.xlabel('Total fertility rate [Children per woman]', labelpad = 10)
plt.ylabel('Life expectancy [years]', labelpad = 10)
# Out:
# Text(0, 0.5, 'Life expectancy [years]')

# %% [markdown]
# ### Create gif with plots for each year from 1960 to 2015
#
# Prepare dataframe with year as coulmns

# %%
df9 = df2.reset_index()
df7 = pd.merge(df9, continents, left_on='level_0', right_on='country')
df7 = df7.set_index(['level_0', 'level_1'])
df7 = df7.stack()
df7 = df7.unstack((1,2))
df7
# Out:
# level_1          1800                                                   \
#             fertility lifeexp   population      continent      country
# level_0
# Afghanistan         7   28.21     3.28e+06           Asia  Afghanistan
# Albania           4.6    35.4       410445         Europe      Albania
# Algeria          6.99   28.82  2.50322e+06         Africa      Algeria
# Andorra           NaN     NaN         2654         Europe      Andorra
# Angola           6.93   26.98  1.56703e+06         Africa       Angola
# ...               ...     ...          ...            ...          ...
# Venezuela        5.63    32.2       718000  South America    Venezuela
# Vietnam           4.7      32    6.551e+06           Asia      Vietnam
# Yemen            6.88   23.39    2.593e+06           Asia        Yemen
# Zambia           6.71    32.6       747000         Africa       Zambia
# Zimbabwe         6.75    33.7  1.08581e+06         Africa     Zimbabwe
#
# level_1          1801                                          1802  ...  \
#             fertility lifeexp      continent      country fertility  ...
# level_0                                                              ...
# Afghanistan         7    28.2           Asia  Afghanistan         7  ...
# Albania           4.6    35.4         Europe      Albania       4.6  ...
# Algeria          6.99   28.82         Africa      Algeria      6.99  ...
# Andorra           NaN     NaN            NaN          NaN       NaN  ...
# Angola           6.93   26.98         Africa       Angola      6.93  ...
# ...               ...     ...            ...          ...       ...  ...
# Venezuela        5.63    32.2  South America    Venezuela      5.64  ...
# Vietnam           4.7      32           Asia      Vietnam       4.7  ...
# Yemen            6.88   23.39           Asia        Yemen      6.88  ...
# Zambia           6.71    32.6         Africa       Zambia      6.71  ...
# Zimbabwe         6.75    33.7         Africa     Zimbabwe      6.75  ...
#
# level_1               2014                   2015                       \
#                  continent      country fertility lifeexp   population
# level_0
# Afghanistan           Asia  Afghanistan      4.47    53.8  3.25266e+07
# Albania             Europe      Albania      1.78      78  2.89668e+06
# Algeria             Africa      Algeria      2.71    76.4  3.96665e+07
# Andorra             Europe      Andorra       NaN    84.8        70473
# Angola              Africa       Angola      5.65    59.6   2.5022e+07
# ...                    ...          ...       ...     ...          ...
# Venezuela    South America    Venezuela      2.34    74.8  3.11081e+07
# Vietnam               Asia      Vietnam       1.7    75.4  9.34476e+07
# Yemen                 Asia        Yemen      3.83      66  2.68322e+07
# Zambia              Africa       Zambia      5.59    56.7  1.62118e+07
# Zimbabwe            Africa     Zimbabwe      3.35    59.3  1.56028e+07
#
# level_1                                    2016
#                  continent      country lifeexp      continent      country
# level_0
# Afghanistan           Asia  Afghanistan   52.72           Asia  Afghanistan
# Albania             Europe      Albania    78.1         Europe      Albania
# Algeria             Africa      Algeria    76.5         Africa      Algeria
# Andorra             Europe      Andorra    84.8         Europe      Andorra
# Angola              Africa       Angola      60         Africa       Angola
# ...                    ...          ...     ...            ...          ...
# Venezuela    South America    Venezuela    74.8  South America    Venezuela
# Vietnam               Asia      Vietnam    75.6           Asia      Vietnam
# Yemen                 Asia        Yemen   64.92           Asia        Yemen
# Zambia              Africa       Zambia    57.1         Africa       Zambia
# Zimbabwe            Africa     Zimbabwe   61.69         Africa     Zimbabwe
#
# [176 rows x 948 columns]

# %% [markdown]
# Loop through the years

# %%
for i in range(1960,2016):
    df8 = df7[i]
    c_size = df8['population']/100_000
    sns.set(font_scale=1.6)
    fig = df8.plot.scatter('fertility', 'lifeexp', s=c_size, figsize=(12,8), c=cmap, alpha=0.6).get_figure()
    plt.axis((0, 10, 0, 100))
    plt.title(str(i), y= 1.02, fontsize = 30, weight='bold')
    plt.xlabel('Total fertility rate [children per woman]', labelpad = 10)
    plt.ylabel('Life expectancy [years]', labelpad = 10)
    filename = 'figures/lifeexp_{}.png'.format(i)
    plt.savefig(filename)
    plt.close()

from IPython.display import Image
Image(url='figures/lifeexp_2000.png')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1960
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-a19dc52bcbce> in <module>
#       1 for i in range(1960,2016):
# ----> 2     df8 = df7[i]
#       3     c_size = df8['population']/100_000
#       4     sns.set(font_scale=1.6)
#       5     fig = df8.plot.scatter('fertility', 'lifeexp', s=c_size, figsize=(12,8), c=cmap, alpha=0.6).get_figure()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1960

# %% [markdown]
# Create gif with imageio

# %%
images = []

for i in range(1960,2016):
    filename = 'figures/lifeexp_{}.png'.format(i)
    images.append(imageio.imread(filename))
    
imageio.mimsave('gapminder2.gif', images, fps=20)

# %%
from IPython.display import Image
Image(url='gapminder2.gif')
# Out:
# <img src="gapminder2.gif"/>

# %% [markdown]
# ## Some stuff on sizes of dots or circles
#
# ### Matplotlib is very smart. The area of the circles is directly related to the data you pass for the argument s. That makes the viewer percieve the size of the circles with the correct proportions.
# The circle at x=10 is about double the size of the circle at x=5.

# %%
x = [5, 10, 15]
y = [1, 1, 1]
s = [500, 1000, 1500]

plt.figure(figsize=(12,4))
plt.scatter(x, y, s=s)
plt.axis((0, 20, 0, 2))
# Out:
# (0, 20, 0, 2)

# %% [markdown]
# ### In other plotting tools, the argument for a circle size is usually the radius. When the respective data is taken as the radius, the view will perceive the size of the circles incorrectly. Here is an example of the same diagram produced in R.
# The circle at x=10 is about double the size of the circle at x=5.
# In that case, the square root of the data should be passed as an argument.

# %%
Image(url='Rplot_circles.png')
# Out:
# <img src="Rplot_circles.png"/>
