# %%
from PIL import Image, ImageEnhance, ImageOps
import cv2
import pytesseract

# %%
im = Image.open('nummernschild.png')

# %%
text = pytesseract.image_to_string(im)

# %%
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=299x168 at 0x127B2F890>

# %%
text
# Out:
# 'Al AIC°HH88 |'

# %%
cover = Image.open('bookcover2.jpg')
cover_large =  ImageOps.scale(cover, 3)
cover_large
# Out:
# <PIL.Image.Image image mode=RGB size=354x540 at 0x12ABA2F50>

# %%
grayscale = ImageOps.grayscale(cover_large)
grayscale
# Out:
# <PIL.Image.Image image mode=L size=354x540 at 0x10E283910>

# %%
enhancer = ImageEnhance.Contrast(grayscale)
enhanced = enhancer.enhance(1.2)
enhanced
# Out:
# <PIL.Image.Image image mode=L size=354x540 at 0x12ABA2D10>

# %%
invert = ImageOps.invert(enhanced)
invert
# Out:
# <PIL.Image.Image image mode=L size=354x540 at 0x12A765810>

# %%
pytesseract.image_to_string(invert)
# Out:
# 'Teercuee'
